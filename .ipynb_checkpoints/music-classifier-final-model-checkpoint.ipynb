# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.metrics import ConfusionMatrixDisplay, accuracy_score, confusion_matrix

from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from tensorflow import keras
from keras.callbacks import EarlyStopping
from keras.layers import Dense, Input, Dropout, BatchNormalization

from sklearn.model_selection import cross_val_score
from sklearn.pipeline import make_pipeline
import joblib
from tensorflow.keras.models import load_model

# %% [markdown]
# # 1 - Load dataset

# %%
data = pd.read_csv('./Data/final_dataset.csv')
data.head()
# Out:
#       id  seen_by_model  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0  15195              1          0.514968         0.154703  0.119834
# 1  15196              1          0.353071         0.089672  0.115684
# 2  15197              1          0.246922         0.071203  0.142179
# 3  15198              1          0.196268         0.059665  0.175184
# 4  15199              1          0.228941         0.065195  0.104522
#
#     rms_var  spectral_centroid_mean  spectral_centroid_var  \
# 0  0.002413             2926.867063          744776.204049
# 1  0.001929             2571.077081          768422.807371
# 2  0.000467             2157.290460          255102.946465
# 3  0.004511             1789.064529          519864.355368
# 4  0.001217             1967.592425          479578.810131
#
#    spectral_bandwidth_mean  spectral_bandwidth_var  ...  mfcc18_mean  \
# 0              3026.757776           143256.463037  ...     6.642057
# 1              2504.260526           136867.750979  ...     4.723323
# 2              2583.825093           128457.268251  ...    -0.330528
# 3              1920.455324           265704.613172  ...    -0.877409
# 4              2381.893832           261899.758287  ...     2.810957
#
#    mfcc18_var  mfcc19_mean  mfcc19_var  mfcc20_mean  mfcc20_var  label  \
# 0  146.515152     7.042427  112.527679    10.134043  111.212082      7
# 1  100.448593    -4.376332   77.169662     3.271257   84.937950      7
# 2   51.709942    -3.030965   52.976002     3.077600   42.835842      7
# 3   38.965206    -4.683223   47.049496    -1.194212   41.838902      7
# 4  101.239632    -4.355564  105.928963    -0.081612   78.802841      7
#
#              createdAt            updatedAt  deletedAt
# 0  2021-11-23 00:52:25  2021-11-23 00:52:25        NaN
# 1  2021-11-23 00:52:25  2021-11-23 00:52:25        NaN
# 2  2021-11-23 00:52:25  2021-11-23 00:52:25        NaN
# 3  2021-11-23 00:52:25  2021-11-23 00:52:25        NaN
# 4  2021-11-23 00:52:25  2021-11-23 00:52:25        NaN
#
# [5 rows x 61 columns]

# %%
data.columns
# Out:
# Index(['id', 'seen_by_model', 'chroma_stft_mean', 'chroma_stft_var',
#        'rms_mean', 'rms_var', 'spectral_centroid_mean',
#        'spectral_centroid_var', 'spectral_bandwidth_mean',
#        'spectral_bandwidth_var', 'rolloff_mean', 'rolloff_var',
#        'zero_crossing_rate_mean', 'zero_crossing_rate_var', 'harmony_mean',
#        'harmony_var', 'tempo', 'mfcc1_mean', 'mfcc1_var', 'mfcc2_mean',
#        'mfcc2_var', 'mfcc3_mean', 'mfcc3_var', 'mfcc4_mean', 'mfcc4_var',
#        'mfcc5_mean', 'mfcc5_var', 'mfcc6_mean', 'mfcc6_var', 'mfcc7_mean',
#        'mfcc7_var', 'mfcc8_mean', 'mfcc8_var', 'mfcc9_mean', 'mfcc9_var',
#        'mfcc10_mean', 'mfcc10_var', 'mfcc11_mean', 'mfcc11_var', 'mfcc12_mean',
#        'mfcc12_var', 'mfcc13_mean', 'mfcc13_var', 'mfcc14_mean', 'mfcc14_var',
#        'mfcc15_mean', 'mfcc15_var', 'mfcc16_mean', 'mfcc16_var', 'mfcc17_mean',
#        'mfcc17_var', 'mfcc18_mean', 'mfcc18_var', 'mfcc19_mean', 'mfcc19_var',
#        'mfcc20_mean', 'mfcc20_var', 'label', 'createdAt', 'updatedAt',
#        'deletedAt'],
#       dtype='object')

# %%
drop_layers = ['id', 'seen_by_model', 'createdAt', 'updatedAt', 'deletedAt']
data = data.drop(columns=drop_layers)
data.head()
# Out:
#    chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0          0.514968         0.154703  0.119834  0.002413
# 1          0.353071         0.089672  0.115684  0.001929
# 2          0.246922         0.071203  0.142179  0.000467
# 3          0.196268         0.059665  0.175184  0.004511
# 4          0.228941         0.065195  0.104522  0.001217
#
#    spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# 0             2926.867063          744776.204049              3026.757776
# 1             2571.077081          768422.807371              2504.260526
# 2             2157.290460          255102.946465              2583.825093
# 3             1789.064529          519864.355368              1920.455324
# 4             1967.592425          479578.810131              2381.893832
#
#    spectral_bandwidth_var  rolloff_mean   rolloff_var  ...  mfcc16_var  \
# 0           143256.463037   6760.151775  2.644778e+06  ...  113.660576
# 1           136867.750979   5252.178063  2.112718e+06  ...  111.430519
# 2           128457.268251   4928.880250  2.100616e+06  ...   37.640495
# 3           265704.613172   3679.929488  2.301348e+06  ...   85.278725
# 4           261899.758287   4322.678115  3.567348e+06  ...   60.897854
#
#    mfcc17_mean  mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  mfcc19_var  \
# 0     0.531954  118.662720     6.642057  146.515152     7.042427  112.527679
# 1    -0.187333  105.414642     4.723323  100.448593    -4.376332   77.169662
# 2    -3.717362   34.108440    -0.330528   51.709942    -3.030965   52.976002
# 3   -13.391407   51.326485    -0.877409   38.965206    -4.683223   47.049496
# 4    -5.820096   65.250710     2.810957  101.239632    -4.355564  105.928963
#
#    mfcc20_mean  mfcc20_var  label
# 0    10.134043  111.212082      7
# 1     3.271257   84.937950      7
# 2     3.077600   42.835842      7
# 3    -1.194212   41.838902      7
# 4    -0.081612   78.802841      7
#
# [5 rows x 56 columns]

# %%
corr = data.corr().label
d = corr[(corr < -0.1) | (corr >= 0.1)]
not_d_cols = list(corr[(corr > -0.1) & (corr < 0.1)].index) + ['label']
print(len(d))
print(not_d_cols)
print(d.index)
pd.DataFrame(data=d)
# Out:
# 36
# ['tempo', 'mfcc1_var', 'mfcc2_var', 'mfcc3_mean', 'mfcc9_var', 'mfcc10_var', 'mfcc11_var', 'mfcc12_var', 'mfcc13_mean', 'mfcc13_var', 'mfcc14_var', 'mfcc15_mean', 'mfcc15_var', 'mfcc16_var', 'mfcc17_mean', 'mfcc17_var', 'mfcc18_var', 'mfcc19_mean', 'mfcc19_var', 'mfcc20_var', 'label']
# Index(['chroma_stft_mean', 'chroma_stft_var', 'rms_mean', 'rms_var',
#        'spectral_centroid_mean', 'spectral_centroid_var',
#        'spectral_bandwidth_mean', 'spectral_bandwidth_var', 'rolloff_mean',
#        'rolloff_var', 'zero_crossing_rate_mean', 'zero_crossing_rate_var',
#        'harmony_mean', 'harmony_var', 'mfcc1_mean', 'mfcc2_mean', 'mfcc3_var',
#        'mfcc4_mean', 'mfcc4_var', 'mfcc5_mean', 'mfcc5_var', 'mfcc6_mean',
#        'mfcc6_var', 'mfcc7_mean', 'mfcc7_var', 'mfcc8_mean', 'mfcc8_var',
#        'mfcc9_mean', 'mfcc10_mean', 'mfcc11_mean', 'mfcc12_mean',
#        'mfcc14_mean', 'mfcc16_mean', 'mfcc18_mean', 'mfcc20_mean', 'label'],
#       dtype='object')
#                             label
# chroma_stft_mean         0.168137
# chroma_stft_var          0.101342
# rms_mean                 0.250687
# rms_var                  0.149902
# spectral_centroid_mean   0.297947
# spectral_centroid_var    0.166563
# spectral_bandwidth_mean  0.378827
# spectral_bandwidth_var   0.165110
# rolloff_mean             0.316482
# rolloff_var              0.249841
# zero_crossing_rate_mean  0.176153
# zero_crossing_rate_var   0.187665
# harmony_mean            -0.189845
# harmony_var             -0.354532
# mfcc1_mean               0.401502
# mfcc2_mean              -0.343443
# mfcc3_var                0.103453
# mfcc4_mean               0.199254
# mfcc4_var                0.229940
# mfcc5_mean               0.119920
# mfcc5_var                0.179138
# mfcc6_mean               0.275908
# mfcc6_var                0.136818
# mfcc7_mean               0.202674
# mfcc7_var                0.169287
# mfcc8_mean               0.238388
# mfcc8_var                0.128009
# mfcc9_mean               0.123050
# mfcc10_mean              0.282693
# mfcc11_mean              0.161325
# mfcc12_mean              0.274675
# mfcc14_mean              0.193357
# mfcc16_mean              0.192424
# mfcc18_mean              0.187652
# mfcc20_mean              0.177040
# label                    1.000000

# %%
fig, ax = plt.subplots(figsize=(20,20))
sns.heatmap(corr.label.values.reshape(56,1),  annot=True, ax=ax)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-190-3a25f317bbe9> in <module>
#       1 fig, ax = plt.subplots(figsize=(20,20))
# ----> 2 sns.heatmap(corr.label.values.reshape(56,1),  annot=True, ax=ax)
#
# AttributeError: 'numpy.float64' object has no attribute 'values'

# %% [markdown]
# # 2 - Pre-process data

# %%
data = data.sample(frac=1)

X = data.drop(columns=not_d_cols)
y = data.label

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
X_train.head()
# Out:
#       chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 1716          0.414032         0.054565  0.116593  0.000217
# 779           0.462657         0.112877  0.100116  0.002143
# 1             0.353071         0.089672  0.115684  0.001929
# 2761          0.533258         0.099348  0.219548  0.005921
# 771           0.495175         0.100544  0.140656  0.002899
#
#       spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# 1716             2353.795011           1.262240e+05              2160.088581
# 779              2677.523624           2.916005e+05              2534.247508
# 1                2571.077081           7.684228e+05              2504.260526
# 2761             3081.433991           1.135337e+06              2773.686400
# 771              2001.822510           6.521444e+05              2256.902631
#
#       spectral_bandwidth_var  rolloff_mean   rolloff_var  ...  mfcc8_mean  \
# 1716            79325.476045   4528.367668  7.429512e+05  ...    9.481945
# 779             67044.239226   5657.661767  1.258448e+06  ...    5.795778
# 1              136867.750979   5252.178063  2.112718e+06  ...    4.290030
# 2761           129072.575924   6309.178555  2.779563e+06  ...    6.547644
# 771            230606.704292   4258.353291  2.725135e+06  ...   -0.301350
#
#        mfcc8_var  mfcc9_mean  mfcc10_mean  mfcc11_mean  mfcc12_mean  \
# 1716   24.183241  -10.032646     1.806884    -4.187940    -4.834543
# 779   260.684814  -11.170466     8.662375    -1.947484     1.313204
# 1     107.836388   -0.082475     6.660373    -7.251233     0.790672
# 2761   89.135750   -3.210121    10.924068    -3.263280     4.481433
# 771   155.470688    2.841107     5.693928   -10.844552     4.772921
#
#       mfcc14_mean  mfcc16_mean  mfcc18_mean  mfcc20_mean
# 1716     4.386966     3.666962     5.713211    -7.536683
# 779      3.211410    -3.304425    -1.976384     2.052995
# 1        4.115472     2.131614     4.723323     3.271257
# 2761     2.619546     1.942045     2.286898     5.458716
# 771      5.494956    -0.317107     2.538990     9.015543
#
# [5 rows x 35 columns]

# %%
count = []
tdf = pd.DataFrame(data=y_test, columns=['label'])

for i in range(10):
    count.append(len(tdf[tdf.label == i]))
    
count
# Out:
# [245, 710, 241, 573, 404, 477, 306, 307, 294, 48]

# %% [markdown]
# ## 2.1 - Scale data

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train = pd.DataFrame(data=scaler.transform(X_train), columns=X_train.columns)
X_test = pd.DataFrame(data=scaler.transform(X_test), columns=X_test.columns)

X_train.head()
# Out:
#    chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0          0.255885        -0.750329 -0.247227 -0.664740
# 1          0.605629         0.946759 -0.427417 -0.179023
# 2         -0.182590         0.271405 -0.257167 -0.233237
# 3          1.113437         0.553014  0.878700  0.773637
# 4          0.839516         0.587810  0.015932  0.011601
#
#    spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# 0                0.286753              -0.773675                -0.086340
# 1                0.675049              -0.417352                 0.473779
# 2                0.547372               0.610018                 0.428889
# 3                1.159520               1.400578                 0.832221
# 4               -0.135420               0.359482                 0.058592
#
#    spectral_bandwidth_var  rolloff_mean  rolloff_var  ...  mfcc8_mean  \
# 0               -0.552187      0.067747    -0.757909  ...    0.586615
# 1               -0.640894      0.671879    -0.444672  ...    0.128940
# 2               -0.136563      0.454960     0.074416  ...   -0.058014
# 3               -0.192867      1.020417     0.479617  ...    0.222292
# 4                0.540509     -0.076701     0.446544  ...   -0.628082
#
#    mfcc8_var  mfcc9_mean  mfcc10_mean  mfcc11_mean  mfcc12_mean  mfcc14_mean  \
# 0  -1.113537   -1.002719    -0.364793    -0.117443    -1.286832     0.486285
# 1   3.086251   -1.178149     0.581566     0.270157    -0.255041     0.263562
# 2   0.371973    0.531413     0.305201    -0.647395    -0.342739     0.434847
# 3   0.039888    0.049188     0.893779     0.042524     0.276690     0.151427
# 4   1.217862    0.982175     0.171790    -1.269041     0.325611     0.696206
#
#    mfcc16_mean  mfcc18_mean  mfcc20_mean
# 0     0.249581     0.770316    -2.018953
# 1    -1.228498    -0.909808     0.064961
# 2    -0.075944     0.554032     0.329698
# 3    -0.116137     0.021690     0.805051
# 4    -0.595124     0.076770     1.577978
#
# [5 rows x 35 columns]

# %%
X_test.head()
# Out:
#    chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0          1.038016         0.437375 -0.018693 -0.420876
# 1         -0.804889         0.660655 -0.878917 -0.633717
# 2         -1.025851        -0.406330 -0.731424 -0.505002
# 3         -0.717744        -0.664326 -0.175440 -0.534129
# 4         -1.784929        -0.545532 -1.052454 -0.538131
#
#    spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# 0                0.399244               1.272321                 0.839106
# 1               -1.700373              -1.021189                -2.176274
# 2                1.414666               0.245237                 0.270836
# 3                0.348697              -0.076541                 0.637386
# 4               -1.900019              -1.035448                -2.675120
#
#    spectral_bandwidth_var  rolloff_mean  rolloff_var  ...  mfcc8_mean  \
# 0                0.383064      0.647317     1.180482  ...    0.088448
# 1               -1.018944     -1.669184    -1.179531  ...   -1.511542
# 2               -0.451969      0.860895    -0.384619  ...    1.552458
# 3                0.040909      0.488984     0.275458  ...    0.286607
# 4               -1.086872     -1.926208    -1.201716  ...   -1.224558
#
#    mfcc8_var  mfcc9_mean  mfcc10_mean  mfcc11_mean  mfcc12_mean  mfcc14_mean  \
# 0   0.148624   -0.852598     0.274901     0.151997     0.696389     0.877523
# 1  -0.914680   -0.964445    -1.455015     0.119247    -1.286048    -0.546930
# 2   0.468918   -1.405738     1.571759    -0.021693    -0.235660    -1.539155
# 3  -0.630285    0.885885     0.356427    -0.291013     0.290349     0.041648
# 4  -0.747721   -0.056967    -2.124992    -1.764973    -2.225508    -0.102940
#
#    mfcc16_mean  mfcc18_mean  mfcc20_mean
# 0     0.104179    -0.145860     0.493358
# 1    -1.381066    -1.673007    -0.836715
# 2    -1.170925     0.308637     0.909053
# 3     0.068601     0.627952     1.063232
# 4    -0.209421    -0.592426     1.118572
#
# [5 rows x 35 columns]

# %% [markdown]
# # 3 - Movel evaluation (Revision)

# %% [markdown]
# ## 3.1 - KNN

# %%
knn_model = KNeighborsClassifier(n_neighbors=2, weights='distance', p=1)
knn_acc = cross_val_score(knn_model, X_train, y_train, cv=5)
print(knn_acc)
print(sum(knn_acc) / 5)
# Out:
# [0.90963139 0.89298454 0.90130797 0.90309156 0.89530042]
# 0.900463174841429

# %% [markdown]
# ## 3.2 - SVM

# %%
svm_model = SVC(kernel='poly', gamma=10, C=1)
svm_acc = cross_val_score(svm_model, X_train, y_train, cv=5)
print(sum(svm_acc) / 5)
# Out:
# 0.8674046010492876

# %% [markdown]
# ## 3.3 - Neural Network

# %%
_X_test, X_val, _y_test, y_val = train_test_split(X_test, y_test, test_size=0.5)

# %%
# Define model
nn_model = keras.Sequential([
    Dense(600, activation='relu', input_shape=[len(X_train.columns)]),
    Dropout(0.5),
    #BatchNormalization(),
    #Dense(600, activation='relu'),
    #Dropout(0.3),
    #BatchNormalization(),
    #Dense(400, activation='relu'),
    #Dropout(0.4),
    #BatchNormalization(),
    Dense(300, activation='relu'),
    Dropout(0.5),
    #BatchNormalization(),
    Dense(128, activation='relu'),
    Dropout(0.4),
    #BatchNormalization(),
    Dense(10, activation='softmax')
])
nn_model.compile(metrics=['accuracy'],
                    loss='sparse_categorical_crossentropy',
                    optimizer='adam')
nn_model.summary()

early_stopping = EarlyStopping(
    patience=10,
    min_delta=0.001,
    restore_best_weights=True
)
history = nn_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=1000,
    callbacks=[early_stopping],
    verbose=1)

nn_prediction_distributions = nn_model.predict(_X_test)
nn_prediction = []
for i in range(len(nn_prediction_distributions)):
    nn_prediction.append(np.argmax(nn_prediction_distributions[i]))
    
nn_acc = accuracy_score(_y_test, nn_prediction)
print("Accuracy: " + str(nn_acc))
# Out:
# Model: "sequential_57"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_256 (Dense)            (None, 600)               21600
# _________________________________________________________________
# dropout_181 (Dropout)        (None, 600)               0
# _________________________________________________________________
# dense_257 (Dense)            (None, 300)               180300
# _________________________________________________________________
# dropout_182 (Dropout)        (None, 300)               0
# _________________________________________________________________
# dense_258 (Dense)            (None, 128)               38528
# _________________________________________________________________
# dropout_183 (Dropout)        (None, 128)               0
# _________________________________________________________________
# dense_259 (Dense)            (None, 10)                1290
# =================================================================
# Total params: 241,718
# Trainable params: 241,718
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 263/263 [==============================] - 1s 3ms/step - loss: 1.2454 - accuracy: 0.5844 - val_loss: 0.8016 - val_accuracy: 0.7449
# Epoch 2/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.8906 - accuracy: 0.7090 - val_loss: 0.7012 - val_accuracy: 0.7743
# Epoch 3/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.7661 - accuracy: 0.7467 - val_loss: 0.6156 - val_accuracy: 0.8020
# Epoch 4/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.7151 - accuracy: 0.7656 - val_loss: 0.5980 - val_accuracy: 0.8048
# Epoch 5/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.6652 - accuracy: 0.7890 - val_loss: 0.5447 - val_accuracy: 0.8297
# Epoch 6/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.6278 - accuracy: 0.7952 - val_loss: 0.5159 - val_accuracy: 0.8364
# Epoch 7/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.5981 - accuracy: 0.8072 - val_loss: 0.4893 - val_accuracy: 0.8408
# Epoch 8/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.5618 - accuracy: 0.8179 - val_loss: 0.4640 - val_accuracy: 0.8558
# Epoch 9/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.5454 - accuracy: 0.8255 - val_loss: 0.4520 - val_accuracy: 0.8602
# Epoch 10/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.5029 - accuracy: 0.8371 - val_loss: 0.4473 - val_accuracy: 0.8586
# Epoch 11/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.4845 - accuracy: 0.8439 - val_loss: 0.4174 - val_accuracy: 0.8802
# Epoch 12/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.4722 - accuracy: 0.8473 - val_loss: 0.4005 - val_accuracy: 0.8819
# Epoch 13/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.4524 - accuracy: 0.8587 - val_loss: 0.3976 - val_accuracy: 0.8796
# Epoch 14/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.4446 - accuracy: 0.8590 - val_loss: 0.3861 - val_accuracy: 0.8780
# Epoch 15/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.4184 - accuracy: 0.8636 - val_loss: 0.3646 - val_accuracy: 0.8930
# Epoch 16/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.4090 - accuracy: 0.8697 - val_loss: 0.3562 - val_accuracy: 0.8996
# Epoch 17/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.3877 - accuracy: 0.8738 - val_loss: 0.3501 - val_accuracy: 0.8957
# Epoch 18/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.3728 - accuracy: 0.8782 - val_loss: 0.3497 - val_accuracy: 0.8930
# Epoch 19/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.3826 - accuracy: 0.8799 - val_loss: 0.3318 - val_accuracy: 0.8974
# Epoch 20/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.3578 - accuracy: 0.8875 - val_loss: 0.3446 - val_accuracy: 0.9029
# Epoch 21/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.3523 - accuracy: 0.8825 - val_loss: 0.3279 - val_accuracy: 0.9013
# Epoch 22/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.3425 - accuracy: 0.8899 - val_loss: 0.3371 - val_accuracy: 0.9007
# Epoch 23/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.3467 - accuracy: 0.8869 - val_loss: 0.3337 - val_accuracy: 0.9002
# Epoch 24/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.3447 - accuracy: 0.8906 - val_loss: 0.3152 - val_accuracy: 0.9068
# Epoch 25/1000
# 263/263 [==============================] - 1s 3ms/step - loss: 0.3182 - accuracy: 0.8942 - val_loss: 0.3081 - val_accuracy: 0.9046
# Epoch 26/1000
# 263/263 [==============================] - 1s 3ms/step - loss: 0.3157 - accuracy: 0.8995 - val_loss: 0.3075 - val_accuracy: 0.9113
# Epoch 27/1000
# 263/263 [==============================] - 1s 3ms/step - loss: 0.3182 - accuracy: 0.8969 - val_loss: 0.3157 - val_accuracy: 0.9068
# Epoch 28/1000
# 263/263 [==============================] - 1s 3ms/step - loss: 0.3186 - accuracy: 0.8949 - val_loss: 0.3083 - val_accuracy: 0.9140
# Epoch 29/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2921 - accuracy: 0.9058 - val_loss: 0.3058 - val_accuracy: 0.9146
# Epoch 30/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2965 - accuracy: 0.9024 - val_loss: 0.3119 - val_accuracy: 0.9074
# Epoch 31/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.3021 - accuracy: 0.9022 - val_loss: 0.3076 - val_accuracy: 0.9085
# Epoch 32/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2911 - accuracy: 0.9069 - val_loss: 0.3145 - val_accuracy: 0.9113
# Epoch 33/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2845 - accuracy: 0.9062 - val_loss: 0.2939 - val_accuracy: 0.9174
# Epoch 34/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2793 - accuracy: 0.9093 - val_loss: 0.3069 - val_accuracy: 0.9151
# Epoch 35/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2829 - accuracy: 0.9083 - val_loss: 0.3044 - val_accuracy: 0.9151
# Epoch 36/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2735 - accuracy: 0.9112 - val_loss: 0.2952 - val_accuracy: 0.9196
# Epoch 37/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2781 - accuracy: 0.9122 - val_loss: 0.2976 - val_accuracy: 0.9146
# Epoch 38/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2722 - accuracy: 0.9134 - val_loss: 0.2964 - val_accuracy: 0.9135
# Epoch 39/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2623 - accuracy: 0.9160 - val_loss: 0.3076 - val_accuracy: 0.9096
# Epoch 40/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2721 - accuracy: 0.9115 - val_loss: 0.2925 - val_accuracy: 0.9218
# Epoch 41/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2592 - accuracy: 0.9166 - val_loss: 0.3042 - val_accuracy: 0.9118
# Epoch 42/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2487 - accuracy: 0.9163 - val_loss: 0.2846 - val_accuracy: 0.9151
# Epoch 43/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2471 - accuracy: 0.9181 - val_loss: 0.2909 - val_accuracy: 0.9168
# Epoch 44/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2616 - accuracy: 0.9169 - val_loss: 0.2821 - val_accuracy: 0.9185
# Epoch 45/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2632 - accuracy: 0.9176 - val_loss: 0.2728 - val_accuracy: 0.9212
# Epoch 46/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2448 - accuracy: 0.9190 - val_loss: 0.2739 - val_accuracy: 0.9257
# Epoch 47/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2483 - accuracy: 0.9178 - val_loss: 0.2704 - val_accuracy: 0.9212
# Epoch 48/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2348 - accuracy: 0.9209 - val_loss: 0.2820 - val_accuracy: 0.9140
# Epoch 49/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2229 - accuracy: 0.9231 - val_loss: 0.2800 - val_accuracy: 0.9185
# Epoch 50/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2303 - accuracy: 0.9238 - val_loss: 0.2803 - val_accuracy: 0.9157
# Epoch 51/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2269 - accuracy: 0.9266 - val_loss: 0.2920 - val_accuracy: 0.9163
# Epoch 52/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2363 - accuracy: 0.9209 - val_loss: 0.2732 - val_accuracy: 0.9174
# Epoch 53/1000
# 263/263 [==============================] - 1s 3ms/step - loss: 0.2304 - accuracy: 0.9227 - val_loss: 0.2775 - val_accuracy: 0.9196
# Epoch 54/1000
# 263/263 [==============================] - 1s 3ms/step - loss: 0.2273 - accuracy: 0.9214 - val_loss: 0.2797 - val_accuracy: 0.9185
# Epoch 55/1000
# 263/263 [==============================] - 1s 3ms/step - loss: 0.2211 - accuracy: 0.9254 - val_loss: 0.2763 - val_accuracy: 0.9212
# Epoch 56/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2235 - accuracy: 0.9283 - val_loss: 0.2812 - val_accuracy: 0.9235
# Epoch 57/1000
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2212 - accuracy: 0.9241 - val_loss: 0.2912 - val_accuracy: 0.9207
# Accuracy: 0.904550499445061

# %%
cm = confusion_matrix(_y_test, nn_prediction)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

# %% [markdown]
# # 4 - Train final models

# %%
X.head()
# Out:
#       chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 5035          0.000000         0.000000  0.000000  0.000000
# 2552          0.222058         0.029720  0.260106  0.001125
# 306           0.432984         0.116189  0.140183  0.001239
# 1655          0.209843         0.035562  0.157989  0.000431
# 7985          0.370385         0.121341  0.045105  0.000420
#
#       spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# 5035                0.000000               0.000000                 0.000000
# 2552             2361.785928          395973.870836              2451.662615
# 306              2522.644299          721467.302230              2483.697979
# 1655             2533.643748           60045.283529              2436.029634
# 7985             1705.805875          197029.361958              1804.509314
#
#       spectral_bandwidth_var  rolloff_mean   rolloff_var  ...  mfcc8_mean  \
# 5035                0.000000      0.000000  0.000000e+00  ...    0.000000
# 2552           160860.568466   5195.896965  2.008947e+06  ...   12.749134
# 306            225216.839865   5116.209125  3.071948e+06  ...    5.278366
# 1655            29063.936845   5117.657995  3.411328e+05  ...   10.422565
# 7985            72157.000897   3373.243717  7.028020e+05  ...   -0.161508
#
#        mfcc8_var  mfcc9_mean  mfcc10_mean  mfcc11_mean  mfcc12_mean  \
# 5035    0.000000    0.000000     0.000000     0.000000     0.000000
# 2552   57.742821  -10.305162     8.566433    -0.597312    -1.269005
# 306    57.571690   -6.270730    -0.955436   -11.834300    -4.025055
# 1655   40.736332    2.626701    10.140564     2.578638     1.709377
# 7985  109.611710   -5.889575    -3.246834   -10.343292     1.974046
#
#       mfcc14_mean  mfcc16_mean  mfcc18_mean  mfcc20_mean
# 5035     0.000000     0.000000     0.000000     0.000000
# 2552     3.089840     2.168136     5.157101     7.099347
# 306     -6.103829    -4.921802    -1.081177     1.801386
# 1655     4.367891     7.870467     8.787485     5.467753
# 7985    -0.054398     0.725202    -3.010236     5.518209
#
# [5 rows x 35 columns]

# %%
X = data.drop(columns=not_d_cols)
y = data.label

final_scaler = StandardScaler()
final_scaler.fit(X)
X_scaled = pd.DataFrame(data=final_scaler.transform(X), columns=X.columns)
X_scaled.head()
# Out:
#    chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0         -2.736809        -2.332314 -1.529310 -0.714814
# 1         -1.133876        -1.470364  1.323142 -0.433348
# 2          0.388704         1.037409  0.008011 -0.404780
# 3         -1.222046        -1.300934  0.203280 -0.607009
# 4         -0.063168         1.186843 -1.034661 -0.609680
#
#    spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# 0               -2.549474              -1.033718                -3.345250
# 1                0.295622              -0.191458                 0.349762
# 2                0.489399               0.500887                 0.398044
# 3                0.502649              -0.905998                 0.326201
# 4               -0.494596              -0.614625                -0.625592
#
#    spectral_bandwidth_var  rolloff_mean  rolloff_var  ...  mfcc8_mean  \
# 0               -1.115573     -2.368844    -1.207840  ...   -0.590273
# 1                0.028938      0.425400     0.006231  ...    0.987438
# 2                0.486828      0.382546     0.648638  ...    0.062927
# 3               -0.908785      0.383325    -1.001682  ...    0.699524
# 4               -0.602181     -0.554784    -0.783114  ...   -0.610260
#
#    mfcc8_var  mfcc9_mean  mfcc10_mean  mfcc11_mean  mfcc12_mean  mfcc14_mean  \
# 0  -1.536157    0.539918    -0.625322     0.609383    -0.483359    -0.348074
# 1  -0.516000   -1.041746     0.563067     0.506042    -0.696129     0.238023
# 2  -0.519024   -0.422531    -0.757866    -1.438054    -1.158228    -1.505879
# 3  -0.816458    0.943071     0.781440     1.055509    -0.196753     0.480450
# 4   0.400380   -0.364030    -1.075743    -1.180096    -0.152377    -0.358392
#
#    mfcc16_mean  mfcc18_mean  mfcc20_mean
# 0    -0.534782    -0.484362    -0.386716
# 1    -0.070234     0.658291     1.161900
# 2    -1.589333    -0.723917     0.006229
# 3     1.151554     1.462671     0.805992
# 4    -0.379399    -1.151336     0.816999
#
# [5 rows x 35 columns]

# %%
final_scaler.n_features_in_
# Out:
# 35

# %%
len(X.columns)
# Out:
# 35

# %% [markdown]
# ## 4.1 - KNN

# %%
final_knn_model = KNeighborsClassifier(n_neighbors=2, weights='distance', p=1)
knn_pipeline = make_pipeline(StandardScaler(), final_knn_model)

knn_pipeline.fit(X, y)
accuracy_score(y, knn_pipeline.predict(X))
# Out:
# 1.0

# %%
# Save model
knn_model_file = "./model-server/ml-models/knn_v2.pkl"  
joblib.dump(knn_pipeline, knn_model_file)
# Out:
# ['./model-server/ml-models/knn_v2.pkl']

# %% [markdown]
# ## 4.2 - Neural Network

# %%
class NNWrapper:
    def __init__(self):
        self.model = keras.Sequential([
            Dense(600, activation='relu', input_shape=[len(X_train.columns)]),
            Dropout(0.5),
            Dense(300, activation='relu'),
            Dropout(0.5),
            Dense(128, activation='relu'),
            Dropout(0.4),
            Dense(10, activation='softmax')
        ])
        self.model.compile(metrics=['accuracy'], loss='sparse_categorical_crossentropy',
            optimizer='adam')
        
    def fit(self, X, y, X_val, y_val):
        early_stopping = EarlyStopping(
            patience=10,
            min_delta=0.001,
            restore_best_weights=True
        )
        return self.model.fit(
            X, y,
            validation_data=(X_val, y_val),
            epochs=1000,
            callbacks=[early_stopping],
            verbose=1)
    
    def predict(self, X):
        nn_prediction_distributions = self.model.predict(X)
        nn_prediction = []
        for i in range(len(nn_prediction_distributions)):
            nn_prediction.append(np.argmax(nn_prediction_distributions[i]))
            
        return nn_prediction

# %%
_X_scaled, X_val, _y_scaled, y_val = train_test_split(X_scaled, y, test_size=0.2)

nn_model = NNWrapper()

nn_model.fit(_X_scaled, _y_scaled, X_val, y_val)
nn_prediction = nn_model.predict(X_scaled)
 
#nn_pipeline = make_pipeline(StandardScaler(), nn_model)
#nn_pipeline.fit(X, y, nnwrapper__X_val=X, nnwrapper__y_val=y)
#nn_prediction = nn_pipeline.predict(X)
    
nn_acc = accuracy_score(y, nn_prediction)
print("Accuracy: " + str(nn_acc))
# Out:
# Epoch 1/1000
# 301/301 [==============================] - 2s 3ms/step - loss: 1.1853 - accuracy: 0.6020 - val_loss: 0.7841 - val_accuracy: 0.7516
# Epoch 2/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.8557 - accuracy: 0.7184 - val_loss: 0.6564 - val_accuracy: 0.7865
# Epoch 3/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.7566 - accuracy: 0.7496 - val_loss: 0.6033 - val_accuracy: 0.8077
# Epoch 4/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.6837 - accuracy: 0.7717 - val_loss: 0.5523 - val_accuracy: 0.8190
# Epoch 5/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.6287 - accuracy: 0.7942 - val_loss: 0.5167 - val_accuracy: 0.8302
# Epoch 6/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.6000 - accuracy: 0.8072 - val_loss: 0.5201 - val_accuracy: 0.8402
# Epoch 7/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.5691 - accuracy: 0.8150 - val_loss: 0.4684 - val_accuracy: 0.8469
# Epoch 8/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.5409 - accuracy: 0.8249 - val_loss: 0.4453 - val_accuracy: 0.8585
# Epoch 9/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.5082 - accuracy: 0.8367 - val_loss: 0.4370 - val_accuracy: 0.8652
# Epoch 10/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4922 - accuracy: 0.8413 - val_loss: 0.4244 - val_accuracy: 0.8618
# Epoch 11/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4713 - accuracy: 0.8467 - val_loss: 0.3999 - val_accuracy: 0.8706
# Epoch 12/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4505 - accuracy: 0.8566 - val_loss: 0.3905 - val_accuracy: 0.8785
# Epoch 13/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4383 - accuracy: 0.8598 - val_loss: 0.3809 - val_accuracy: 0.8885
# Epoch 14/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4277 - accuracy: 0.8627 - val_loss: 0.3741 - val_accuracy: 0.8851
# Epoch 15/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4065 - accuracy: 0.8677 - val_loss: 0.3606 - val_accuracy: 0.8872
# Epoch 16/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3910 - accuracy: 0.8745 - val_loss: 0.3540 - val_accuracy: 0.8926
# Epoch 17/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3996 - accuracy: 0.8741 - val_loss: 0.3327 - val_accuracy: 0.8976
# Epoch 18/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3776 - accuracy: 0.8797 - val_loss: 0.3454 - val_accuracy: 0.8881
# Epoch 19/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3649 - accuracy: 0.8788 - val_loss: 0.3383 - val_accuracy: 0.8910
# Epoch 20/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3491 - accuracy: 0.8909 - val_loss: 0.3319 - val_accuracy: 0.8993
# Epoch 21/1000
# 301/301 [==============================] - 1s 3ms/step - loss: 0.3454 - accuracy: 0.8868 - val_loss: 0.3459 - val_accuracy: 0.8910
# Epoch 22/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3416 - accuracy: 0.8908 - val_loss: 0.3226 - val_accuracy: 0.8955
# Epoch 23/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3451 - accuracy: 0.8927 - val_loss: 0.3362 - val_accuracy: 0.8947
# Epoch 24/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3240 - accuracy: 0.8968 - val_loss: 0.3173 - val_accuracy: 0.9026
# Epoch 25/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3319 - accuracy: 0.8967 - val_loss: 0.3147 - val_accuracy: 0.9047
# Epoch 26/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3230 - accuracy: 0.8995 - val_loss: 0.3004 - val_accuracy: 0.9089
# Epoch 27/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3059 - accuracy: 0.8999 - val_loss: 0.3242 - val_accuracy: 0.9068
# Epoch 28/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3123 - accuracy: 0.9026 - val_loss: 0.3282 - val_accuracy: 0.9005
# Epoch 29/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.2986 - accuracy: 0.9047 - val_loss: 0.3030 - val_accuracy: 0.9039
# Epoch 30/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.2894 - accuracy: 0.9061 - val_loss: 0.3004 - val_accuracy: 0.9084
# Epoch 31/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3083 - accuracy: 0.9016 - val_loss: 0.2945 - val_accuracy: 0.9105
# Epoch 32/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.2885 - accuracy: 0.9078 - val_loss: 0.3020 - val_accuracy: 0.9084
# Epoch 33/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.2905 - accuracy: 0.9075 - val_loss: 0.2974 - val_accuracy: 0.9043
# Epoch 34/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.2976 - accuracy: 0.9026 - val_loss: 0.3038 - val_accuracy: 0.9080
# Epoch 35/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.2723 - accuracy: 0.9077 - val_loss: 0.2866 - val_accuracy: 0.9118
# Epoch 36/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.2723 - accuracy: 0.9124 - val_loss: 0.2882 - val_accuracy: 0.9118
# Epoch 37/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.2656 - accuracy: 0.9118 - val_loss: 0.2830 - val_accuracy: 0.9143
# Epoch 38/1000
# 301/301 [==============================] - 1s 3ms/step - loss: 0.2739 - accuracy: 0.9145 - val_loss: 0.2876 - val_accuracy: 0.9143
# Epoch 39/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.2693 - accuracy: 0.9128 - val_loss: 0.3075 - val_accuracy: 0.9105
# Epoch 40/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.2649 - accuracy: 0.9140 - val_loss: 0.2877 - val_accuracy: 0.9168
# Epoch 41/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.2518 - accuracy: 0.9172 - val_loss: 0.2832 - val_accuracy: 0.9089
# Epoch 42/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.2500 - accuracy: 0.9189 - val_loss: 0.2812 - val_accuracy: 0.9155
# Epoch 43/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.2535 - accuracy: 0.9162 - val_loss: 0.2866 - val_accuracy: 0.9089
# Epoch 44/1000
# 301/301 [==============================] - 1s 3ms/step - loss: 0.2368 - accuracy: 0.9204 - val_loss: 0.2800 - val_accuracy: 0.9105
# Epoch 45/1000
# 301/301 [==============================] - 1s 3ms/step - loss: 0.2485 - accuracy: 0.9152 - val_loss: 0.2793 - val_accuracy: 0.9080
# Epoch 46/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.2354 - accuracy: 0.9180 - val_loss: 0.2942 - val_accuracy: 0.9105
# Epoch 47/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.2511 - accuracy: 0.9176 - val_loss: 0.3018 - val_accuracy: 0.9051
# Epoch 48/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.2511 - accuracy: 0.9172 - val_loss: 0.2874 - val_accuracy: 0.9118
# Epoch 49/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.2375 - accuracy: 0.9258 - val_loss: 0.2924 - val_accuracy: 0.9076
# Epoch 50/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.2429 - accuracy: 0.9177 - val_loss: 0.2824 - val_accuracy: 0.9126
# Epoch 51/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.2291 - accuracy: 0.9255 - val_loss: 0.2819 - val_accuracy: 0.9143
# Epoch 52/1000
# 301/301 [==============================] - 1s 4ms/step - loss: 0.2410 - accuracy: 0.9206 - val_loss: 0.2880 - val_accuracy: 0.9093
# Epoch 53/1000
# 301/301 [==============================] - 1s 2ms/step - loss: 0.2276 - accuracy: 0.9294 - val_loss: 0.2961 - val_accuracy: 0.9097
# Epoch 54/1000
# 301/301 [==============================] - 1s 3ms/step - loss: 0.2294 - accuracy: 0.9263 - val_loss: 0.3047 - val_accuracy: 0.9105
# Accuracy: 0.9576327617779258

# %%
# Save model
scaler_filename = "./model-server/ml-models/scaler_v2.pkl"  
neural_net_model_file = "./model-server/ml-models/neural_net_v4.h5"  
joblib.dump(final_scaler, scaler_filename)
nn_model.model.save(neural_net_model_file)
