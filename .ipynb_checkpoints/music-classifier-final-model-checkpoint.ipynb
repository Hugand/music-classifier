# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.metrics import ConfusionMatrixDisplay, accuracy_score, confusion_matrix

from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from tensorflow import keras
from keras.callbacks import EarlyStopping
from keras.layers import Dense, Input, Dropout, BatchNormalization

from sklearn.model_selection import cross_val_score
from sklearn.pipeline import make_pipeline
import joblib

# %% [markdown]
# # 1 - Load dataset

# %%
data = pd.read_csv('./Data/final_dataset.csv')
data.head()
# Out:
#    id  seen_by_model  chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0   1              1          0.520358         0.124743  0.070391  0.000434
# 1   2              1          0.388348         0.086167  0.297966  0.009691
# 2   3              1          0.518485         0.065370  0.327077  0.006457
# 3   4              1          0.478101         0.118793  0.203072  0.007147
# 4   5              1          0.418904         0.109677  0.126266  0.006128
#
#    spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# 0             2264.917294           5.060068e+05              2847.625596
# 1             2935.985009           9.924919e+05              3311.847002
# 2             2922.966713           1.032951e+06              3093.809771
# 3             2992.777588           6.522995e+05              3067.992091
# 4             3468.342133           2.106551e+06              2846.573847
#
#    spectral_bandwidth_var  ...  mfcc18_mean  mfcc18_var  mfcc19_mean  \
# 0           228497.299297  ...    -4.515758   60.539124    -7.388275
# 1           227928.442456  ...     1.053828   63.267517     4.509480
# 2           251801.103830  ...     4.371969   57.691128     1.573209
# 3           199704.791866  ...    -9.667604   44.565285    -8.366688
# 4           202140.587789  ...    -1.611886   62.417545    -3.372361
#
#    mfcc19_var  mfcc20_mean  mfcc20_var  label            createdAt  \
# 0   51.426353     2.620186   36.707134      7  2021-11-21 20:32:52
# 1   98.980377    -0.402736  119.903381      7  2021-11-21 20:32:52
# 2   73.915237     1.695063   85.998665      7  2021-11-21 20:32:52
# 3   55.856071     0.578032   46.971275      7  2021-11-21 20:32:52
# 4   62.406410    -5.930054   75.245758      7  2021-11-21 20:32:52
#
#              updatedAt  deletedAt
# 0  2021-11-21 20:32:52        NaN
# 1  2021-11-21 20:32:52        NaN
# 2  2021-11-21 20:32:52        NaN
# 3  2021-11-21 20:32:52        NaN
# 4  2021-11-21 20:32:52        NaN
#
# [5 rows x 61 columns]

# %%
data.columns
# Out:
# Index(['id', 'seen_by_model', 'chroma_stft_mean', 'chroma_stft_var',
#        'rms_mean', 'rms_var', 'spectral_centroid_mean',
#        'spectral_centroid_var', 'spectral_bandwidth_mean',
#        'spectral_bandwidth_var', 'rolloff_mean', 'rolloff_var',
#        'zero_crossing_rate_mean', 'zero_crossing_rate_var', 'harmony_mean',
#        'harmony_var', 'tempo', 'mfcc1_mean', 'mfcc1_var', 'mfcc2_mean',
#        'mfcc2_var', 'mfcc3_mean', 'mfcc3_var', 'mfcc4_mean', 'mfcc4_var',
#        'mfcc5_mean', 'mfcc5_var', 'mfcc6_mean', 'mfcc6_var', 'mfcc7_mean',
#        'mfcc7_var', 'mfcc8_mean', 'mfcc8_var', 'mfcc9_mean', 'mfcc9_var',
#        'mfcc10_mean', 'mfcc10_var', 'mfcc11_mean', 'mfcc11_var', 'mfcc12_mean',
#        'mfcc12_var', 'mfcc13_mean', 'mfcc13_var', 'mfcc14_mean', 'mfcc14_var',
#        'mfcc15_mean', 'mfcc15_var', 'mfcc16_mean', 'mfcc16_var', 'mfcc17_mean',
#        'mfcc17_var', 'mfcc18_mean', 'mfcc18_var', 'mfcc19_mean', 'mfcc19_var',
#        'mfcc20_mean', 'mfcc20_var', 'label', 'createdAt', 'updatedAt',
#        'deletedAt'],
#       dtype='object')

# %%
drop_layers = ['id', 'seen_by_model', 'createdAt', 'updatedAt', 'deletedAt']
data = data.drop(columns=drop_layers)
data.head()
# Out:
#    chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0          0.520358         0.124743  0.070391  0.000434
# 1          0.388348         0.086167  0.297966  0.009691
# 2          0.518485         0.065370  0.327077  0.006457
# 3          0.478101         0.118793  0.203072  0.007147
# 4          0.418904         0.109677  0.126266  0.006128
#
#    spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# 0             2264.917294           5.060068e+05              2847.625596
# 1             2935.985009           9.924919e+05              3311.847002
# 2             2922.966713           1.032951e+06              3093.809771
# 3             2992.777588           6.522995e+05              3067.992091
# 4             3468.342133           2.106551e+06              2846.573847
#
#    spectral_bandwidth_var  rolloff_mean   rolloff_var  ...  mfcc16_var  \
# 0           228497.299297   5549.934645  3.866304e+06  ...   51.429020
# 1           227928.442456   7167.740760  4.475303e+06  ...   45.286793
# 2           251801.103830   6414.161471  4.412762e+06  ...   47.677711
# 3           199704.791866   6629.659142  3.007183e+06  ...   41.710487
# 4           202140.587789   6670.986328  4.532121e+06  ...   51.437981
#
#    mfcc17_mean  mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  mfcc19_var  \
# 0   -11.791601   61.902149    -4.515758   60.539124    -7.388275   51.426353
# 1    -3.548585   59.885021     1.053828   63.267517     4.509480   98.980377
# 2     4.113480   43.106792     4.371969   57.691128     1.573209   73.915237
# 3    -6.372496   43.728996    -9.667604   44.565285    -8.366688   55.856071
# 4     0.257360   63.807865    -1.611886   62.417545    -3.372361   62.406410
#
#    mfcc20_mean  mfcc20_var  label
# 0     2.620186   36.707134      7
# 1    -0.402736  119.903381      7
# 2     1.695063   85.998665      7
# 3     0.578032   46.971275      7
# 4    -5.930054   75.245758      7
#
# [5 rows x 56 columns]

# %% [markdown]
# # 2 - Pre-process data

# %%
data = data.sample(frac=1)

X = data.drop(columns='label')
y = data.label

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
X_train.head()
# Out:
#       chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 1088          0.445647         0.040892  0.112758  0.001260
# 2242          0.866035         0.042426  0.103939  0.002963
# 1911          0.411214         0.068370  0.109937  0.000380
# 919           0.529704         0.111861  0.306300  0.013200
# 4682          0.387988         0.071308  0.146778  0.002494
#
#       spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# 1088             2937.168554           2.526353e+05              2355.755808
# 2242             2474.627760           8.624231e+05              2665.515930
# 1911             2639.651043           1.351761e+05              2162.955218
# 919              3587.091793           2.078048e+06              3331.663673
# 4682             2481.645285           6.162475e+05              2636.143950
#
#       spectral_bandwidth_var  rolloff_mean   rolloff_var  ...  mfcc16_mean  \
# 1088            49638.754744   5577.679349  7.504309e+05  ...     6.372021
# 2242           241069.394534   5267.021484  3.922925e+06  ...    -3.362451
# 1911            74039.848626   5022.039889  7.857289e+05  ...     4.993399
# 919            271823.255974   7599.150203  4.847391e+06  ...    -5.429938
# 4682           198610.816050   5386.447942  2.298724e+06  ...     7.174257
#
#       mfcc16_var  mfcc17_mean  mfcc17_var  mfcc18_mean  mfcc18_var  \
# 1088   27.265720   -10.362926   28.816181     3.603544   19.636404
# 2242   18.087191    -4.179109   38.837769    -3.880088   34.328777
# 1911   33.945454   -13.448551   27.037601     1.260451   55.560299
# 919    68.862976     2.024814   35.295528    -0.863002   52.081692
# 4682   48.923168     4.773321   45.061665     2.125057  109.337898
#
#       mfcc19_mean  mfcc19_var  mfcc20_mean  mfcc20_var
# 1088    -7.128216   29.361816     0.659773   24.878040
# 2242    -4.803296   40.840969    -5.040445   14.943357
# 1911    -9.596294   50.394417    -3.816816   37.552311
# 919     -0.519932   74.730034    -0.118360  103.176666
# 4682    -0.957720   84.987930    -3.571458   64.637894
#
# [5 rows x 55 columns]

# %% [markdown]
# ## 2.1 - Scale data

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train = pd.DataFrame(data=scaler.transform(X_train), columns=X_train.columns)
X_test = pd.DataFrame(data=scaler.transform(X_test), columns=X_test.columns)

X_train.head()
# Out:
#    chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0          0.374242        -0.930588 -0.308053 -0.413249
# 1          3.121260        -0.887260 -0.436706  0.056187
# 2          0.149235        -0.154427 -0.349214 -0.655860
# 3          0.923507         1.074035  2.515336  2.878783
# 4         -0.002534        -0.071433  0.188226 -0.073243
#
#    spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# 0                0.961323              -0.399000                 0.191891
# 1                0.338723               0.961354                 0.764204
# 2                0.560852              -0.661036                -0.164328
# 3                1.836148               3.673250                 1.994980
# 4                0.348169               0.412170                 0.709937
#
#    spectral_bandwidth_var  rolloff_mean  rolloff_var  ...  mfcc16_mean  \
# 0               -0.676255      0.593879    -0.593543  ...     0.848910
# 1                1.152561      0.403123     1.476585  ...    -0.849893
# 2               -0.443141      0.252695    -0.570511  ...     0.608321
# 3                1.446365      1.835139     2.079822  ...    -1.210699
# 4                0.746937      0.476455     0.416755  ...     0.988912
#
#    mfcc16_var  mfcc17_mean  mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  \
# 0   -0.644875    -1.069292   -0.627839     0.528043   -0.877072    -0.899838
# 1   -0.906077     0.027054   -0.353603    -0.908411   -0.478902    -0.442605
# 2   -0.454784    -1.616351   -0.676509     0.078296    0.096483    -1.385225
# 3    0.538897     1.126964   -0.450534    -0.329293    0.002211     0.399788
# 4   -0.028549     1.614254   -0.183289     0.244253    1.553883     0.313690
#
#    mfcc19_var  mfcc20_mean  mfcc20_var
# 0   -0.591739     0.292338   -0.684924
# 1   -0.322105    -0.799196   -0.899901
# 2   -0.097704    -0.564884   -0.410665
# 3    0.473917     0.143333    1.009383
# 4    0.714865    -0.517900    0.175441
#
# [5 rows x 55 columns]

# %%
X_test.head()
# Out:
#    chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0          0.675033         1.343858  0.292644 -0.315721
# 1         -0.260505         0.275154 -0.721918 -0.649896
# 2         -0.745124         0.018201  0.302336  0.336834
# 3         -0.046601         0.080700  0.094392 -0.051871
# 4          0.534866         1.431581 -0.322481 -0.313515
#
#    spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# 0               -0.224387              -0.375517                -0.359896
# 1               -1.142253              -0.195321                -0.439209
# 2               -0.033917              -0.503307                -0.074868
# 3               -0.127982               0.473181                 0.066120
# 4               -0.391707               0.269799                -0.239923
#
#    spectral_bandwidth_var  rolloff_mean  rolloff_var  ...  mfcc16_mean  \
# 0               -0.263175     -0.171280    -0.431815  ...    -1.024132
# 1                0.646835     -1.061287     0.523453  ...    -2.526544
# 2               -0.455686      0.103538    -0.453503  ...    -0.439187
# 3               -0.292618      0.084722     0.050411  ...    -0.305377
# 4                1.551056     -0.236985     0.796676  ...    -0.159901
#
#    mfcc16_var  mfcc17_mean  mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  \
# 0   -0.698072    -1.851034   -0.791666    -1.007326   -0.853750    -1.217397
# 1    0.479162    -0.800363   -0.954590    -1.743505   -0.312924    -0.152582
# 2   -0.402492    -1.003380    0.498708     1.206809    0.903517     0.478804
# 3   -0.609854    -0.491326   -0.531431    -0.095422   -0.574753    -1.339426
# 4   -0.045297    -0.753471    0.150508     0.048364   -0.491664     0.537307
#
#    mfcc19_var  mfcc20_mean  mfcc20_var
# 0   -0.605521    -0.356357   -0.354270
# 1   -0.438687     0.727428   -0.128788
# 2    0.999119     0.856459    0.329546
# 3    0.397263     0.821784   -0.510528
# 4    1.045022     0.795213    0.141993
#
# [5 rows x 55 columns]

# %% [markdown]
# # 3 - Movel evaluation (Revision)

# %% [markdown]
# ## 3.1 - KNN

# %%
knn_model = KNeighborsClassifier(n_neighbors=2, weights='distance', p=1)
svm_acc = cross_val_score(knn_model, X_train, y_train, cv=5)
print(sum(cv_acc) / 5)
# Out:
# 0.9069292620888453

# %% [markdown]
# ## 3.2 - SVM

# %%
svm_model = SVC(kernel='poly', gamma=10, C=1)
svm_acc = cross_val_score(svm_model, X_train, y_train, cv=5)
print(sum(svm_acc) / 5)
# Out:
# 0.8657676930670732

# %% [markdown]
# ## 3.3 - Neural Network

# %%
_X_test, X_val, _y_test, y_val = train_test_split(X_test, y_test, test_size=0.5)

# %%
# Define model
nn_model = keras.Sequential([
    Dense(512, activation='relu', input_shape=[len(X_train.columns)]),
    Dropout(0.2),
    BatchNormalization(),
    Dense(600, activation='relu'),
    Dropout(0.3),
    BatchNormalization(),
    Dense(256, activation='relu'),
    Dropout(0.2),
    BatchNormalization(),
    Dense(128, activation='relu'),
    Dropout(0.3),
    BatchNormalization(),
    Dense(64, activation='relu'),
    Dropout(0.3),
    BatchNormalization(),
    Dense(10, activation='softmax')
])
nn_model.compile(metrics=['accuracy'],
                    loss='sparse_categorical_crossentropy',
                    optimizer='adam')
nn_model.summary()

early_stopping = EarlyStopping(
    patience=10,
    min_delta=0.001,
    restore_best_weights=True
)
history = nn_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=1000,
    callbacks=[early_stopping],
    verbose=1)

nn_prediction_distributions = nn_model.predict(_X_test)
nn_prediction = []
for i in range(len(nn_prediction_distributions)):
    nn_prediction.append(np.argmax(nn_prediction_distributions[i]))
    
nn_acc = accuracy_score(_y_test, nn_prediction)
print("Accuracy: " + str(nn_acc))
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_24 (Dense)             (None, 512)               28672
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 512)               0
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 512)               2048
# _________________________________________________________________
# dense_25 (Dense)             (None, 600)               307800
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 600)               0
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 600)               2400
# _________________________________________________________________
# dense_26 (Dense)             (None, 256)               153856
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 256)               0
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 256)               1024
# _________________________________________________________________
# dense_27 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 128)               0
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 128)               512
# _________________________________________________________________
# dense_28 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 64)                0
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 64)                256
# _________________________________________________________________
# dense_29 (Dense)             (None, 10)                650
# =================================================================
# Total params: 538,370
# Trainable params: 535,250
# Non-trainable params: 3,120
# _________________________________________________________________
# Epoch 1/1000
# 207/207 [==============================] - 2s 6ms/step - loss: 1.7642 - accuracy: 0.3989 - val_loss: 1.0496 - val_accuracy: 0.6370
# Epoch 2/1000
# 207/207 [==============================] - 1s 7ms/step - loss: 1.2688 - accuracy: 0.5658 - val_loss: 0.8282 - val_accuracy: 0.7076
# Epoch 3/1000
# 207/207 [==============================] - 1s 5ms/step - loss:
1000
# 207/207 [==============================] - 1s 5ms/step - loss: 0.2352 - accuracy: 0.9286 - val_loss: 0.3160 - val_accuracy: 0.8976
# Epoch 49/1000
# 207/207 [==============================] - 1s 5ms/step - loss: 0.2437 - accuracy: 0.9228 - val_loss: 0.3165 - val_accuracy: 0.9018
# Epoch 50/1000
# 207/207 [==============================] - 1s 5ms/step - loss: 0.2266 - accuracy: 0.9263 - val_loss: 0.3309 - val_accuracy: 0.9054
# Epoch 51/1000
# 207/207 [==============================] - 1s 5ms/step - loss: 0.2447 - accuracy: 0.9230 - val_loss: 0.3266 - val_accuracy: 0.9103
# Epoch 52/1000
# 207/207 [==============================] - 1s 5ms/step - loss: 0.2217 - accuracy: 0.9293 - val_loss: 0.2875 - val_accuracy: 0.9117
# Epoch 53/1000
# 207/207 [==============================] - 1s 6ms/step - loss: 0.2296 - accuracy: 0.9274 - val_loss: 0.3010 - val_accuracy: 0.9096
# Epoch 54/1000
# 207/207 [==============================] - 1s 5ms/step - loss: 0.2141 - accuracy: 0.9343 - val_loss: 0.3376 - val_accuracy: 0.9061
# Epoch 55/1000
# 207/207 [==============================] - 1s 5ms/step - loss: 0.2273 - accuracy: 0.9299 - val_loss: 0.2994 - val_accuracy: 0.9117
# Epoch 56/1000
# 207/207 [==============================] - 1s 5ms/step - loss: 0.1957 - accuracy: 0.9364 - val_loss: 0.2859 - val_accuracy: 0.9131
# Epoch 57/1000
# 207/207 [==============================] - 1s 5ms/step - loss: 0.2087 - accuracy: 0.9345 - val_loss: 0.3420 - val_accuracy: 0.9047
# Epoch 58/1000
# 207/207 [==============================] - 1s 5ms/step - loss: 0.2084 - accuracy: 0.9349 - val_loss: 0.3035 - val_accuracy: 0.9075
# Epoch 59/1000
# 207/207 [==============================] - 1s 5ms/step - loss: 0.1980 - accuracy: 0.9366 - val_loss: 0.3043 - val_accuracy: 0.9124
# Epoch 60/1000
# 207/207 [==============================] - 1s 6ms/step - loss: 0.2168 - accuracy: 0.9277 - val_loss: 0.3232 - val_accuracy: 0.9018
# Epoch 61/1000
# 207/207 [==============================] - 1s 6ms/step - loss: 0.1970 - accuracy: 0.9337 - val_loss: 0.3033 - val_accuracy: 0.9103
# Epoch 62/1000
# 207/207 [==============================] - 1s 5ms/step - loss: 0.1951 - accuracy: 0.9392 - val_loss: 0.3146 - val_accuracy: 0.9040
# Epoch 63/1000
# 207/207 [==============================] - 1s 6ms/step - loss: 0.2026 - accuracy: 0.9370 - val_loss: 0.3090 - val_accuracy: 0.9089
# Epoch 64/1000
# 207/207 [==============================] - 2s 8ms/step - loss: 0.1966 - accuracy: 0.9375 - val_loss: 0.3089 - val_accuracy: 0.9124
# Epoch 65/1000
# 207/207 [==============================] - 1s 6ms/step - loss: 0.1864 - accuracy: 0.9399 - val_loss: 0.2946 - val_accuracy: 0.9160
# Epoch 66/1000
# 207/207 [==============================] - 1s 5ms/step - loss: 0.1805 - accuracy: 0.9390 - val_loss: 0.3055 - val_accuracy: 0.9153
# Accuracy: 0.8990112994350282

# %% [markdown]
# # 4 - Train final models

# %%
X = data.drop(columns='label')
y = data.label

final_scaler = StandardScaler()
X_scaled = pd.DataFrame(data=final_scaler.fit_transform(X), columns=X.columns)
X_scaled.head()
# Out:
#    chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0         -1.169350        -1.239786  0.552619 -0.085852
# 1          0.922817         0.550178  0.217169  0.658467
# 2          0.000360         0.190034  1.078578  1.287329
# 3          0.655892         1.731624  1.653297  0.344723
# 4          0.537196         0.292100  0.300893  0.632034
#
#    spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# 0                0.677596               1.224507                 1.333004
# 1               -0.290407               0.059269                -0.401443
# 2                1.864106               1.816759                 1.899589
# 3                1.296539              -0.214385                 1.325409
# 4                0.296852               0.232449                -0.091431
#
#    spectral_bandwidth_var  rolloff_mean  rolloff_var  ...  mfcc16_mean  \
# 0                0.509376      0.887122     1.705112  ...    -0.382886
# 1                0.133376     -0.273277     0.180680  ...     0.819552
# 2               -0.048042      1.923231     0.528810  ...    -0.861074
# 3               -0.464779      1.404184    -0.331356  ...    -0.875757
# 4               -0.204895      0.204034    -0.057508  ...     0.175630
#
#    mfcc16_var  mfcc17_mean  mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  \
# 0    3.223533     0.439659    2.499254    -0.768231    1.188300    -1.114470
# 1   -0.841767     0.282689   -0.606899     0.732668   -0.475100    -0.180289
# 2    1.654077     1.051769    2.054396    -0.081254    0.718237     1.057724
# 3    1.319459    -0.224471    2.827072    -1.144964    3.312181     0.845762
# 4    0.236233    -0.660574    0.398881     0.094677    0.385163    -0.215438
#
#    mfcc19_var  mfcc20_mean  mfcc20_var
# 0    0.786940    -1.370432    1.887132
# 1   -0.570234    -0.078228   -0.696439
# 2    1.348150     0.299284    1.796697
# 3    0.284989    -0.506875    1.767331
# 4    1.630722     0.753921    0.146740
#
# [5 rows x 55 columns]

# %% [markdown]
# ## 4.1 - KNN

# %%
final_knn_model = KNeighborsClassifier(n_neighbors=2, weights='distance', p=1)
knn_pipeline = make_pipeline(StandardScaler(), final_knn_model)

knn_pipeline.fit(X, y)
accuracy_score(y, knn_pipeline.predict(X))
# Out:
# 0.9989406779661016

# %%
# Save model
knn_model_file = "./ml-models/knn.pkl"  
joblib.dump(knn_pipeline, knn_model_file)
# Out:
# ['./ml-models/knn.pkl']

# %% [markdown]
# ## 4.2 - Neural Network

# %%
class NNWrapper:
    def __init__(self):
        self.model = keras.Sequential([
            Dense(512, activation='relu', input_shape=[len(X_train.columns)]),
            Dropout(0.2),
            BatchNormalization(),
            Dense(600, activation='relu'),
            Dropout(0.3),
            BatchNormalization(),
            Dense(256, activation='relu'),
            Dropout(0.2),
            BatchNormalization(),
            Dense(128, activation='relu'),
            Dropout(0.3),
            BatchNormalization(),
            Dense(64, activation='relu'),
            Dropout(0.3),
            BatchNormalization(),
            Dense(10, activation='softmax')
        ])
        self.model.compile(metrics=['accuracy'], loss='sparse_categorical_crossentropy',
            optimizer='adam')
        
    def fit(self, X, y, X_val, y_val):
        early_stopping = EarlyStopping(
            patience=10,
            min_delta=0.001,
            restore_best_weights=True
        )
        return self.model.fit(
            X, y,
            validation_data=(X_val, y_val),
            epochs=1000,
            callbacks=[early_stopping],
            verbose=1)
    
    def predict(self, X):
        nn_prediction_distributions = self.model.predict(X)
        nn_prediction = []
        for i in range(len(nn_prediction_distributions)):
            nn_prediction.append(np.argmax(nn_prediction_distributions[i]))
            
        return nn_prediction

# %%
nn_model = NNWrapper()
 
nn_pipeline = make_pipeline(StandardScaler(), nn_model)
nn_pipeline.fit(X, y, nnwrapper__X_val=X, nnwrapper__y_val=y)
nn_prediction = nn_pipeline.predict(X)
# 295/295 [==============================] - 2s 6ms/step - loss: 0.4047 - accuracy: 0.8710 - val_loss: 249170.6562 - val_accuracy: 0.1059
# Epoch 20/1000
# 295/295 [==============================] - 2s 7ms/step - loss: 0.3924 - accuracy: 0.8767 - val_loss: 415391.0625 - val_accuracy: 0.1110
# Epoch 21/1000
# 295/295 [==============================] - 2s 6ms/step - loss: 0.3700 - accuracy: 0.8829 - val_loss: 374302.0312 - val_accuracy: 0.1121
# Epoch 22/1000
# 295/295 [==============================] - 2s 5ms/step - loss: 0.3732 - accuracy: 0.8824 - val_loss: 255898.4688 - val_accuracy: 0.1072
# Epoch 23/1000
# 295/295 [==============================] - 1s 5ms/step - loss: 0.3505 - accuracy: 0.8925 - val_loss: 360616.5312 - val_accuracy: 0.1076
# Epoch 24/1000
# 295/295 [==============================] - 2s 6ms/step - loss: 0.3589 - accuracy: 0.8850 - val_loss: 288393.4688 - val_accuracy: 0.1056
# Accuracy: 0.9505296610169491

# %%
# Save model
neural_net_model_file = "./ml-models/neural_net.pkl"  
joblib.dump(nn_pipeline, neural_net_model_file)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-96-04238a3c1c47> in <module>
#       1 # Save model
#       2 neural_net_model_file = "./ml-models/neural_net.pkl"
# ----> 3 joblib.dump(nn_pipeline, neural_net_model_file)
#
# ~/Library/Python/3.8/lib/python/site-packages/joblib/numpy_pickle.py in dump(value, filename, compress, protocol, cache_size)
#     478     elif is_filename:
#     479         with open(filename, 'wb') as f:
# --> 480             NumpyPickler(f, protocol=protocol).dump(value)
#     481     else:
#     482         NumpyPickler(filename, protocol=protocol).dump(value)
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/pickle.py in dump(self, obj)
#     483         if self.proto >= 4:
#     484             self.framer.start_framing()
# --> 485         self.save(obj)
#     486         self.write(STOP)
#     487         self.framer.end_framing()
#
# ~/Library/Python/3.8/lib/python/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     599
#     600         # Save the reduce() output and finally memoize the object
# --> 601         self.save_reduce(obj=obj, *rv)
#     602
#     603     def persistent_id(self, obj):
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     713         if state is not None:
#     714             if state_setter is None:
# --> 715                 save(state)
#     716                 write(BUILD)
#     717             else:
#
# ~/Library/Python/3.8/lib/python/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     556             f = self.dispatch.get(t)
#     557             if f is not None:
# --> 558                 f(self, obj)  # Call unbound method with explicit self
#     559                 return
#     560
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/pickle.py in save_dict(self, obj)
#     967
#     968         self.memoize(obj)
# --> 969         self._batch_setitems(obj.items())
#     970
#     971     dispatch[dict] = save_dict
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/pickle.py in _batch_setitems(self, items)
#     993                 for k, v in tmp:
#     994                     save(k)
# --> 995                     save(v)
#     996                 write(SETITEMS)
#     997             elif n:
#
# ~/Library/Python/3.8/lib/python/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     556             f = self.dispatch.get(t)
#     557             if f is not None:
# --> 558                 f(self, obj)  # Call unbound method with explicit self
#     559                 return
#     560
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/pickle.py in save_list(self, obj)
#     927
#     928         self.memoize(obj)
# --> 929         self._batch_appends(obj)
#     930
#     931     dispatch[list] = save_list
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/pickle.py in _batch_appends(self, items)
#     951                 write(MARK)
#     952                 for x in tmp:
# --> 953                     save(x)
#     954                 write(APPENDS)
#     955             elif n:
#
# ~/Library/Python/3.8/lib/python/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     556             f = self.dispatch.get(t)
#     557             if f is not None:
# --> 558                 f(self, obj)  # Call unbound method with explicit self
#     559                 return
#     560
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/pickle.py in save_tuple(self, obj)
#     882         if n <= 3 and self.proto >= 2:
#     883             for element in obj:
# --> 884                 save(element)
#     885             # Subtle.  Same as in the big comment below.
#     886             if id(obj) in memo:
#
# ~/Library/Python/3.8/lib/python/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     599
#     600         # Save the reduce() output and finally memoize the object
# --> 601         self.save_reduce(obj=obj, *rv)
#     602
#     603     def persistent_id(self, obj):
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     713         if state is not None:
#     714             if state_setter is None:
# --> 715                 save(state)
#     716                 write(BUILD)
#     717             else:
#
# ~/Library/Python/3.8/lib/python/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     556             f = self.dispatch.get(t)
#     557             if f is not None:
# --> 558                 f(self, obj)  # Call unbound method with explicit self
#     559                 return
#     560
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/pickle.py in save_dict(self, obj)
#     967
#     968         self.memoize(obj)
# --> 969         self._batch_setitems(obj.items())
#     970
#     971     dispatch[dict] = save_dict
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/pickle.py in _batch_setitems(self, items)
#     998                 k, v = tmp[0]
#     999                 save(k)
# -> 1000                 save(v)
#    1001                 write(SETITEM)
#    1002             # else tmp is empty, and we're done
#
# ~/Library/Python/3.8/lib/python/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     599
#     600         # Save the reduce() output and finally memoize the object
# --> 601         self.save_reduce(obj=obj, *rv)
#     602
#     603     def persistent_id(self, obj):
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     713         if state is not None:
#     714             if state_setter is None:
# --> 715                 save(state)
#     716                 write(BUILD)
#     717             else:
#
# ~/Library/Python/3.8/lib/python/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     556             f = self.dispatch.get(t)
#     557             if f is not None:
# --> 558                 f(self, obj)  # Call unbound method with explicit self
#     559                 return
#     560
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/pickle.py in save_dict(self, obj)
#     967
#     968         self.memoize(obj)
# --> 969         self._batch_setitems(obj.items())
#     970
#     971     dispatch[dict] = save_dict
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/pickle.py in _batch_setitems(self, items)
#     993                 for k, v in tmp:
#     994                     save(k)
# --> 995                     save(v)
#     996                 write(SETITEMS)
#     997             elif n:
#
# ~/Library/Python/3.8/lib/python/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     599
#     600         # Save the reduce() output and finally memoize the object
# --> 601         self.save_reduce(obj=obj, *rv)
#     602
#     603     def persistent_id(self, obj):
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     713         if state is not None:
#     714             if state_setter is None:
# --> 715                 save(state)
#     716                 write(BUILD)
#     717             else:
#
# ~/Library/Python/3.8/lib/python/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     556             f = self.dispatch.get(t)
#     557             if f is not None:
# --> 558                 f(self, obj)  # Call unbound method with explicit self
#     559                 return
#     560
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/pickle.py in save_dict(self, obj)
#     967
#     968         self.memoize(obj)
# --> 969         self._batch_setitems(obj.items())
#     970
#     971     dispatch[dict] = save_dict
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/pickle.py in _batch_setitems(self, items)
#     993                 for k, v in tmp:
#     994                     save(k)
# --> 995                     save(v)
#     996                 write(SETITEMS)
#     997             elif n:
#
# ~/Library/Python/3.8/lib/python/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     556             f = self.dispatch.get(t)
#     557             if f is not None:
# --> 558                 f(self, obj)  # Call unbound method with explicit self
#     559                 return
#     560
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/pickle.py in save_dict(self, obj)
#     967
#     968         self.memoize(obj)
# --> 969         self._batch_setitems(obj.items())
#     970
#     971     dispatch[dict] = save_dict
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/pickle.py in _batch_setitems(self, items)
#     992                 write(MARK)
#     993                 for k, v in tmp:
# --> 994                     save(k)
#     995                     save(v)
#     996                 write(SETITEMS)
#
# ~/Library/Python/3.8/lib/python/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     574                 reduce = getattr(obj, "__reduce_ex__", None)
#     575                 if reduce is not None:
# --> 576                     rv = reduce(self.proto)
#     577                 else:
#     578                     reduce = getattr(obj, "__reduce__", None)
#
# TypeError: cannot pickle 'weakref' object
